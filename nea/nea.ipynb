# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('nea.csv')

sns.barplot(df, x='Benchmark', y='Runtime (s)', hue='Language')
plt.xlabel(None)
plt.show()
